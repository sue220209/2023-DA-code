# %% [markdown]
# # matplotlib 중급
#
# # 설치 점검 및 모듈 확인

# %%
import sys
print(sys.version)
sys.path
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# ['C:\\2023-da',
#  'C:\\Users\\102\\anaconda3\\python39.zip',
#  'C:\\Users\\102\\anaconda3\\DLLs',
#  'C:\\Users\\102\\anaconda3\\lib',
#  'C:\\Users\\102\\anaconda3',
#  '',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\102\\.ipython']

# %%
import site
site.getsitepackages()
# Out:
# ['C:\\Users\\102\\anaconda3', 'C:\\Users\\102\\anaconda3\\lib\\site-packages']

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.5.2'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.5'

# %%
#폰트 설정
mpl.rc('font', family='Malgun Gothic')
#유니코드에서 음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [10,20,30,40])
plt.title('plotting')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(7, 4))
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

x = np.linspace(-2 * np.pi, 2 * np.pi, 200) #0에서 2*pi까지 경계선을 포함해 199등분
plt.plot(x, np.sin(x)*10)
plt.plot(x, x**2)
plt.plot(x, 2 * x**2 - 3 * x)

plt.grid(True)
plt.title('다양한 그래프')
plt.show()

# %% [markdown]
# # histogram 돗수분포포

# %%
import matplotlib.pyplot as plt

plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 7, 8, 10])
plt.show()

# %% [markdown]
# # 난수와 돗수분포표

# %%
import random
random.randint(1, 6)
# Out:
# 4

# %%
import random as rd

dice = []

for i in range(10):
    dice.append(random.randint(1, 6))
    
#plt.hist(dice, bins=6)
plt.hist(dice, bins=np.arange(0.5, 7.5), rwidth=0.9)
plt.show()

# %% [markdown]
# # boxplot()

# %%
import matplotlib.pyplot as plt
import random

result = []
for i in range(13):
    result.append(random.randint(1, 1000))
    
print(sorted(result))

plt.boxplot(result, whis = 0.5)
plt.show()
# Out:
# [186, 219, 291, 305, 377, 483, 517, 610, 614, 788, 824, 826, 931]

# %% [markdown]
# # SUBPLOT 그리기

# %%
import matplotlib.pyplot as plt

#서브플롯 생성
plt.subplot(2, 1, 1) #2행 1열의 서브플룻 중 첫 번째
plt.subplot(2, 1, 2) #2행 1열의 서브플롯 중 두 번째

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

ax1 = plt.subplot(2, 1, 1)
plt.plot(np.random.randint(1, 10, 10), 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Demped oscillation')
print(ax1)

#ax2 = plt.suvplot(2,1,2)
ax2 = plt.subplot(2,1,2)
plt.plot(np.arange(10), np.arange(10)*2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.53;0.775x0.35)
# AxesSubplot(0.125,0.11;0.775x0.35)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 2) #2행 2열의 서브플룻

axes[0, 0].plot([1, 2, 3, 4])
axes[0, 0].set_title("Subplot 1")

axes[0, 1].plot([4, 3, 2, 1])
axes[0, 1].set_title("Subplot 2")

axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4], bins=5)
axes[1, 0].set_title("Subplot 3")

axes[1, 1].scatter([1, 2, 3, 4], [4, 3, 2, 1])
axes[1, 1].set_title("Subplot 4")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

fig, axes = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(8, 6))
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=.05)
#plt.subplots_adjust(wspace=None, hspace=None) #적정한 공간 비우기

plt.tight_layout()
plt.show()
